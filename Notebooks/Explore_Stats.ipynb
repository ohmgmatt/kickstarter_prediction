# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import norm
from scipy.stats import f_oneway
from scipy.stats import ttest_ind
from collections import Counter

# %%
df = pd.read_pickle('kickstarter_analysis.pkl')

# %%
df.head(2)
# Out:
#                                                blurb country  \
# 0  Ginger KICK! is back for the holidays with ama...      US
# 1  Let's go to the movies on the L.A. River! Help...      US
#
#            created_at currency            deadline         launched_at  \
# 0 2017-11-05 12:05:03      USD 2017-11-12 20:33:24 2017-11-05 20:33:24
# 1 2013-02-26 21:38:16      USD 2013-04-11 17:20:16 2013-03-12 17:20:16
#
#                              slug  spotlight  staff_pick       state  ...  \
# 0       ginger-kick-holiday-cheer       True       False  successful  ...
# 1  la-river-bike-in-movie-theater       True        True  successful  ...
#
#    usd_goal percent_goal vid_usage reach_goal  \
# 0      50.0      1650.00     False       True
# 1   10000.0       105.45     False       True
#
#                            usd_rewards description_len blurb_len  slug_len  \
# 0  [1.0, 6.0, 12.0, 30.0, 50.0, 100.0]          4138.0     127.0        25
# 1     [10.0, 25.0, 50.0, 100.0, 250.0]          1812.0     133.0        30
#
#    med_rewards reward_len
# 0         21.0          6
# 1         50.0          5
#
# [2 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['blurb', 'country', 'created_at', 'currency', 'deadline', 'launched_at',
#        'slug', 'spotlight', 'staff_pick', 'state', 'usd_pledged',
#        'category_name', 'location_displayable_name', 'location_country',
#        'location_state', 'web_url', 'description', 'img_count', 'vid_count',
#        'category_core', 'usd_goal', 'percent_goal', 'vid_usage', 'reach_goal',
#        'usd_rewards', 'description_len', 'blurb_len', 'slug_len',
#        'med_rewards', 'reward_len'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.boxplot(x = 'reach_goal', y='usd_goal', data = df, ax = ax, showfliers = False ,showmeans=True)
ax.set_title('Boxplot of Goals by Success/Fail')
plt.savefig('img/stats_boxplot_successfail_goal.png', layout='tight')
plt.show()

# %%
print(np.mean(df[df['reach_goal']==True].usd_goal))
print(np.mean(df[df['reach_goal']==False].usd_goal))
# Out:
# 9167.35957656551
# 81797.5185975289

# %%
fig, ax = plt.subplots(figsize = (5, 4))
sns.boxplot(x = 'reach_goal', y='usd_goal', data = df, ax = ax)
ax.set_title('Boxplot of Goals by Success/Fail')
plt.savefig('img/stats_boxplot_successfail_goal_outliers.png', layout='tight')
plt.show()

# %%
success = df[df['reach_goal']==True]
fail = df[df['reach_goal']==False]

sci_t, sci_pvalue = ttest_ind(success.usd_goal,fail.usd_goal)
print('t-test: {} \np-value: {}'.format(sci_t, sci_pvalue))
# Out:
# t-test: -13.39865449055265
# p-value: 6.459399966744276e-41

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.boxplot(x = 'reach_goal', y='med_rewards', data = df, ax = ax, showfliers = False ,showmeans=True)
ax.set_title('Boxplot of Med Rewards by Success/Fail')
plt.savefig('img/stats_boxplot_successfail_medreward.png', layout='tight')
plt.show()

# %%
print(np.median(fail.med_rewards.dropna()))
print(np.median(success.med_rewards.dropna()))
# Out:
# 50.0
# 60.0

# %%
sci_t, sci_pvalue = ttest_ind(success.med_rewards.dropna(),fail.med_rewards.dropna())
print('t-test: {} \np-value: {}'.format(sci_t, sci_pvalue))
# Out:
# t-test: -35.08942832431375
# p-value: 9.049711214255251e-269

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.boxplot(x = 'reach_goal', y='description_len', data = df, ax = ax, showfliers = False ,showmeans=True)
ax.set_title('Boxplot of Description Length by Success/Fail')
plt.savefig('img/stats_boxplot_successfail_desclen.png', layout='tight')
plt.show()

# %%
print(np.mean(fail.description_len.dropna()))
print(np.mean(success.description_len.dropna()))
# Out:
# 2434.7315906487906
# 3773.641021615115

# %%
sci_t, sci_pvalue = ttest_ind(success.description_len.dropna(),fail.description_len.dropna())
print('t-test: {} \np-value: {}'.format(sci_t, sci_pvalue))
# Out:
# t-test: 89.20488613516447
# p-value: 0.0

# %%
reached_goal = df[df.reach_goal == True]
missed_goal = df[df.reach_goal == False]

# %%
fig, ax = plt.subplots(figsize = (10, 5))

ax = plt.hist(reached_goal.usd_goal)
ax = plt.semilogy()
plt.show()

# %%
usd_reached_goal = reached_goal[(reached_goal.usd_goal <= 1000000) & (reached_goal.usd_goal >= 1000)].usd_goal
usd_missed_goal = missed_goal[(missed_goal.usd_goal <= 1000000) & (missed_goal.usd_goal >= 1000)].usd_goal

# %%
def bootstrap_replicate_1d(data, func):
    return func(np.random.choice(data, size=len(data)))

def draw_bs_reps(data, func, size=1):
    """Draw bootstrap replicates."""

    # Initialize array of replicates: bs_replicates
    bs_replicates = np.empty(size)

    # Generate replicates
    for i in range(size):
        bs_replicates[i] = bootstrap_replicate_1d(data, func)

    return bs_replicates

# %% [markdown]
# ## Bootstrap Mean of USD Goal by Success

# %%
N_rep = 10000
bs_reach_usd = draw_bs_reps(usd_reached_goal, np.mean, N_rep)
bs_reach_low, bs_reach_high = np.percentile(bs_reach_usd, [2.5, 97.5])     
print(bs_reach_low, bs_reach_high)


bs_miss_usd = draw_bs_reps(usd_missed_goal, np.mean, N_rep)
bs_miss_low, bs_miss_high = np.percentile(bs_miss_usd, [2.5, 97.5])
print(bs_miss_low, bs_miss_high)
# Out:
# 11143.494201873154 11501.16832592962
# 31245.71380655574 32506.573691552912

# %%
obs_reach_usd = np.mean(usd_reached_goal)
obs_missed_usd = np.mean(usd_missed_goal)

# %%
fig, ax = plt.subplots(2, 1, figsize = (16, 6))
bins = 40

ax = plt.subplot(2,1,1)
ax = plt.hist(bs_reach_usd, color = 'b', bins = bins)
plt.axvline(bs_reach_low, color = 'k', linestyle = '--')
plt.axvline(bs_reach_high, color = 'k', linestyle = '--')
plt.xlabel('Mean (USD Goal)')
plt.ylabel('Amount')
plt.title('Bootstrap Means for Successful - USD Goal')


ax = plt.subplot(2,1,2)
ax.set_xlim([8000, 35000])
ax = plt.hist(bs_reach_usd, color = 'b', bins = bins)
ax = plt.hist(bs_miss_usd, color = 'r', bins = bins)
plt.axvline(bs_miss_low, color = 'k', linestyle = '--')
plt.axvline(bs_miss_high, color = 'k', linestyle = '--')
plt.xlabel('Mean (USD Goal)')
plt.ylabel('Amount')
plt.title('Bootstrap Means for Failed - USD Goal')

plt.tight_layout()
plt.show()

# fig.savefig("img/bootstrap_means_usd_goal", bbox_inches='tight')

# %% [markdown]
# ## Hypothesis Test
# Mean difference between successful and failed goals is statistically different.

# %%
usd_goal = df.usd_goal
mean_diff = np.mean(usd_reached_goal) - np.mean(usd_missed_goal)
mean_goal = np.mean(usd_goal)

reach_goal_shifted = usd_reached_goal - np.mean(usd_reached_goal) + mean_goal
missed_goal_shifted = usd_missed_goal - np.mean(usd_missed_goal) + mean_goal

# %%
bs_reach = draw_bs_reps(reach_goal_shifted, np.mean, size = 10000)
bs_missed = draw_bs_reps(missed_goal_shifted, np.mean, size = 10000)

# %%
bs_mean_diff = bs_reach -  bs_missed

# %%
p = np.sum(bs_mean_diff < mean_diff) / len(bs_mean_diff)

# %%
print("The p-value is {}".format(p))
# Out:
# The p-value is 0.0

# %%
fig, ax = plt.subplots(figsize = (16, 6))

ax = plt.hist(bs_mean_diff, bins = 40)
plt.axvline(mean_diff, color = 'r', linestyle = '-.')
plt.title('USD Goal: Observed Mean Difference compared to Bootstrapped Means Difference')
plt.xlabel('Mean Difference')

## fig.savefig("img/bootstrap_mean_difference_usd_goal", bbox_inches='tight')
# Out:
# Text(0.5, 0, 'Mean Difference')

# %%
mean_diff
# Out:
# -72630.1590209634

# %% [markdown]
# ## Description Length Analysis

# %%
df.description_len
print(np.mean(df.description_len))
# Out:
# 3188.2674521354934

# %%
s_d_len = reached_goal[(reached_goal.description_len <= 40000)].description_len.dropna()
f_d_len = missed_goal[(missed_goal.description_len <= 40000)].description_len.dropna()

# %%
print(np.mean(s_d_len))
print(np.mean(f_d_len))
# Out:
# 3773.047972449599
# 2434.0312744226158

# %%
N_rep = 10000

bs_sdlen = draw_bs_reps(s_d_len, np.mean, N_rep)
bs_fdlen = draw_bs_reps(f_d_len, np.mean, N_rep)

sd_low, sd_high = np.percentile(bs_sdlen, [2.5, 97.5])
fd_low, fd_high = np.percentile(bs_fdlen, [2.5, 97.5])

# %%
fig, ax = plt.subplots(figsize = (20, 4))
ax = plt.hist(bs_sdlen, color = 'b')
ax = plt.hist(bs_fdlen, color = 'r')

plt.title('Bootstrap Mean Description Length by Success')
plt.xlabel('Mean Description Length')
plt.show()
fig.savefig("img/bootstrap_mean_description_length", bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize = (15, 5))
ax = plt.hist(bs_sdlen, color = 'b', bins = 50)
plt.axvline(sd_low, color = 'k', linestyle = '--')
plt.axvline(sd_high, color = 'k', linestyle = '--')
plt.title('Bootstrap Mean Description Length - Success')
plt.show()

fig.savefig("img/bootstrap_mean_description_len_success", bbox_inches='tight')
print(sd_high - sd_low)

fig, ax = plt.subplots(figsize = (15, 5))
ax = plt.hist(bs_fdlen, color = 'r', bins = 50)
plt.axvline(fd_low, color = 'k', linestyle = '--')
plt.axvline(fd_high, color = 'k', linestyle = '--')
plt.title('Bootstrap Mean Description Length - Fail')
plt.show()

fig.savefig("img/bootstrap_mean_description_len_fail", bbox_inches='tight')
print(fd_high - fd_low)
# Out:
# 42.29523441915944
# 38.92008583286133

# %%
print(np.max(bs_sdlen) - np.min(bs_sdlen))
print(np.max(bs_fdlen) - np.min(bs_fdlen))
# Out:
# 78.94384198295893
# 73.27574312124398

# %% [markdown]
# ## Median Rewards Analysis

# %%
df.columns
# Out:
# Index(['blurb', 'country', 'created_at', 'currency', 'deadline', 'launched_at',
#        'slug', 'spotlight', 'staff_pick', 'state', 'usd_pledged',
#        'category_name', 'location_displayable_name', 'location_country',
#        'location_state', 'web_url', 'description', 'img_count', 'vid_count',
#        'category_core', 'usd_goal', 'percent_goal', 'vid_usage', 'reach_goal',
#        'usd_rewards', 'description_len', 'blurb_len', 'slug_len',
#        'med_rewards', 'reward_len'],
#       dtype='object')

# %%
reached_goal.med_rewards.describe()
# Out:
# count    95529.000000
# mean        95.995209
# std        157.679686
# min          0.000000
# 25%         35.000000
# 50%         60.000000
# 75%        100.000000
# max       9000.000000
# Name: med_rewards, dtype: float64

# %%
missed_goal.med_rewards.describe()
# Out:
# count    74205.000000
# mean       167.067784
# std        599.919409
# min          0.000000
# 25%         25.000000
# 50%         50.000000
# 75%        101.000000
# max      11201.630000
# Name: med_rewards, dtype: float64

# %%
s_med_r = reached_goal.med_rewards.dropna()
f_med_r = missed_goal.med_rewards.dropna()
print(np.mean(s_med_r))
print(np.mean(f_med_r))
# Out:
# 95.9952089417878
# 167.06778397682018

# %%
N_rep = 10000

bs_smedr = draw_bs_reps(s_med_r, np.mean, N_rep)
bs_fmedr = draw_bs_reps(f_med_r, np.mean, N_rep)

smr_low, smr_high = np.percentile(bs_smedr, [2.5, 97.5])
fmr_low, fmr_high = np.percentile(bs_fmedr, [2.5, 97.5])

# %%
fig, ax = plt.subplots(figsize = (20, 4))
ax = plt.hist(bs_smedr, color = 'b')
ax = plt.hist(bs_fmedr, color = 'r')
plt.title('Bootstrap of Average of Median Rewards')
plt.show()
fig.savefig("img/bootstrap_median_rewards", bbox_inches='tight')

fig, ax = plt.subplots(figsize = (15, 5))
ax = plt.hist(bs_smedr, color = 'b', bins = 50)
plt.axvline(smr_low, color = 'k', linestyle = '--')
plt.axvline(smr_high, color = 'k', linestyle = '--')
plt.title('Bootstrapped Mean: Success - Median Rewards')
plt.show()
fig.savefig("img/bootstrap_median_rewards_success", bbox_inches='tight')
print("95%CI range for success: ", smr_high - smr_low)

fig, ax = plt.subplots(figsize = (15, 5))
ax = plt.hist(bs_fmedr, color = 'r', bins = 50)
plt.axvline(fmr_low, color = 'k', linestyle = '--')
plt.axvline(fmr_high, color = 'k', linestyle = '--')
plt.title('Bootstrapped Mean: Failed - Median Rewards')
plt.show()
fig.savefig("img/bootstrap_median_rewards_fail", bbox_inches='tight')
print("95%CI range for failed: ",fmr_high - fmr_low)
# Out:
# 95%CI range for success:  2.010426053868457
# 95%CI range for failed:  8.602564662084774

# %%
tested = ttest_ind(df[df.reach_goal == True].med_rewards.dropna(), df[df.reach_goal == False].med_rewards.dropna(), equal_var = False)

# %%
tested
# Out:
# Ttest_indResult(statistic=-31.43946495044649, pvalue=1.1217106210955935e-215)

# %%
fig, ax = plt.subplots(figsize = (10, 7))

sns.boxplot(x = 'reach_goal', y='med_rewards', data = df, ax = ax, showfliers = False ,showmeans=True)
ax.set_title('Success/Fail to Median Rewards')
plt.savefig('img/successfail_med_reward_boxplot.png')

plt.show()

# %%
df.groupby(by='reach_goal').med_rewards.mean().sort_values()
# Out:
# reach_goal
# True      95.995209
# False    167.067784
# Name: med_rewards, dtype: float64

# %% [markdown]
# ## Category Success

# %%
df.groupby(by='category_core').reach_goal.mean().sort_values()
## Same as % total success since it's sum of all 1s over total.
# Out:
# category_core
# food            0.296531
# journalism      0.314895
# technology      0.364666
# photography     0.412310
# crafts          0.424502
# art             0.579940
# fashion         0.584753
# film & video    0.585289
# games           0.617355
# design          0.617842
# theater         0.645216
# music           0.673374
# publishing      0.702714
# dance           0.791487
# comics          0.794365
# Name: reach_goal, dtype: float64

# %%
def success_rate(data):
    return np.sum(data) / len(data)

# %%
categories = list(df.category_core.unique())

# %%
## Getting categories into individual fields
cc_analysis = dict()

for i, cc in enumerate(categories):
    cc_analysis[cc] = df[df.category_core == cc].reach_goal
    
## Running bootstrap
bscc_analysis = dict()

N_rep = 1000
for c in cc_analysis:
    bscc_analysis[c] = draw_bs_reps(cc_analysis[c], success_rate, N_rep)

# %%
colors = ['#e6194B', '#3cb44b', '#ffe119',
'#4363d8', '#f58231', '#911eb4', 
'#42d4f4', '#f032e6', '#bfef45', 
'#fabebe', '#469990', '#e6beff', 
'#9A6324', '#fffac8', '#800000']
cat_color = dict(zip(categories, colors))

# %%
fig, ax = plt.subplots(figsize = (20, 5))
ax.set_xlim(.27, .9)


for bs in bscc_analysis:
    ax = plt.hist(bscc_analysis[bs], alpha = 0.5, bins = 25, label = bs, color = cat_color[bs])

plt.title("Bootstrap Success Rate by Category")
plt.xlabel('Success Rate')
plt.ylabel('Frequency')
plt.legend()
plt.show()
fig.savefig("img/bootstrap_success_rate_by_category", bbox_inches='tight')

# %%
low_half = df.groupby(by='category_core').reach_goal.mean().sort_values().values<.5
low_half_list = list(df.groupby(by='category_core').reach_goal.mean().sort_values()[low_half].index)
high_half = df.groupby(by='category_core').reach_goal.mean().sort_values().values>=.5
high_half_list = list(df.groupby(by='category_core').reach_goal.mean().sort_values()[high_half].index)

# %%
fig, ax = plt.subplots(figsize = (20, 3))
for bs in low_half_list:
    ax = plt.hist(bscc_analysis[bs], alpha = 0.5, bins = 30, label = bs, color = cat_color[bs])
plt.title("Bootstrap Success Rate by Category (Less than 50%)")
plt.xlabel('Success Rate')
plt.ylabel('Frequency')
plt.legend()
plt.show()
fig.savefig("img/bootstrap_success_rate_category_lower", bbox_inches='tight')

fig, ax = plt.subplots(figsize = (20, 3))
for bs in high_half_list:
    ax = plt.hist(bscc_analysis[bs], alpha = 0.5, bins = 30, label = bs, color = cat_color[bs])
plt.title("Bootstrap Success Rate by Category (More than 50%)")
plt.xlabel('Success Rate')
plt.ylabel('Frequency')
plt.legend()
plt.show()
fig.savefig("img/bootstrap_success_rate_category_high", bbox_inches='tight')

# %%
high = 0
highest = ''
low = 100
lowest = ''

for bs in bscc_analysis:
    conf_test = np.percentile(bscc_analysis[bs], 100) - np.percentile(bscc_analysis[bs], 0)
    if conf_test > high:
        high = conf_test
        highest = bs
    if conf_test < low:
        low = conf_test
        lowest = bs
print("The highest spread in a category category is {} with {}".format(highest, high))
print("The lowest spread in a category is {} with {}".format(lowest, low))
# Out:
# The highest spread in a category category is dance with 0.049218490189557706
# The lowest spread in a category is music with 0.019027141060489194

# %% [markdown]
# ## Video Usage

# %%
## Getting categories into individual fields
vu_analysis = dict()

for i, vu in enumerate(categories):
    vu_analysis[vu] = df[df.category_core == vu].vid_usage
    
## Running bootstrap
bsvu_analysis = dict()

N_rep = 10000
for c in vu_analysis:
    bsvu_analysis[c] = draw_bs_reps(vu_analysis[c], success_rate, N_rep)

# %%
fig, ax = plt.subplots(figsize = (20, 5))

for bs in bsvu_analysis:
    ax = plt.hist(bsvu_analysis[bs], alpha = 0.5, bins = 25, label = bs, color = cat_color[bs])

plt.title("Bootstrap Video Usage by Categories")
plt.xlabel('Vid Usage Percent')
plt.ylabel('Frequency')
plt.legend()
plt.show()
fig.savefig("img/bootstrap_video_usage", bbox_inches='tight')

# %% [markdown]
# ## Categories to USD Goal

# %% [markdown]
# ### Cat - USD Goal: Bootstrap

# %%
## Getting categories into individual fields
ug_analysis = dict()

for ug in categories:
    ug_analysis[ug] = df[df.category_core == ug].usd_goal
    
## Running bootstrap
bsug_analysis = dict()

N_rep = 10000
for c in ug_analysis:
    bsug_analysis[c] = draw_bs_reps(ug_analysis[c], np.mean, N_rep)

# %%
df[df.category_core == 'journalism'].usd_goal.describe()
# Out:
# count    3.706000e+03
# mean     5.596014e+04
# std      1.668095e+06
# min      1.000000e+00
# 25%      1.500000e+03
# 50%      5.000000e+03
# 75%      1.272092e+04
# max      1.000000e+08
# Name: usd_goal, dtype: float64

# %%
bs_journalism_usd = draw_bs_reps(df[df.category_core == 'journalism'].usd_goal, np.mean, 10000)

# %%
fig, ax = plt.subplots(figsize = (10, 5))
ax = plt.hist(bs_journalism_usd, alpha = 0.5, bins = 100, label = 'journalism')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10, 5))
ax = plt.hist(df[(df.category_core == 'journalism') & (df.usd_goal <= 50000)].usd_goal, bins = 200)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (5,20))
ax.set_ylim([-1000, 200000])
sns.boxplot(data=df[df.category_core=='journalism'], x='category_core', y = 'usd_goal')

# %%
fig, ax = plt.subplots(figsize = (20, 5))

for bs in bsug_analysis:
    ax = plt.hist(bsug_analysis[bs], alpha = 0.5, bins = 25, label = bs)
    
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20, 5))
for bs in ['journalism', 'food']:
    ax = plt.hist(bsug_analysis[bs], alpha = 0.5, bins = 100, label = bs)
    
plt.legend()
plt.show()

# %% [markdown]
# ### Cat - USD Goal: Boxplots

# %%
fig, ax = plt.subplots(figsize = (20, 10))

ax.set_ylim([-1000, 120000])
sns.boxplot(x = 'category_core', y='usd_goal', data = df, ax = ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10, 4))

sns.boxplot(x = 'category_core', y='usd_goal', data = df, ax = ax)
plt.show()

# %%
medians = df.groupby(['category_core'])['usd_goal'].agg(['median','count']).sort_values(by = 'median', 
                                                                                           ascending = False)

fig, ax = plt.subplots(figsize = (16, 8))
ax.set_ylim([-10000, 119000])

sns.boxplot(x='category_core', y='usd_goal', data=df, ax = ax,
           order = list(medians.index), showfliers = False)


pos = range(len(medians))
for tick,label in zip(pos,ax.get_xticklabels()):
    ax.text(pos[tick], 115000,"n: " + str(medians['count'][tick]),
            ha='center', size='small', color='k', weight='light')
    ax.text(pos[tick], -7000, 'median\n'+str(medians['median'][tick]),
           ha = 'center', size='small', color='k', weight='light')

ax.set_ylabel('USD Goal')
ax.set_xlabel('Core Category')
ax.set_title("USD Goal by Category ")
    
plt.show()

fig.savefig("img/category_to_usd_goal_sorted_ids", bbox_inches='tight')

# %%
medians = df.groupby(['category_core'])['usd_goal'].agg(['median','count']).sort_values(by = 'median', 
                                                                                           ascending = False)

fig, ax = plt.subplots(figsize = (16, 4))

sns.boxplot(x='category_core', y='usd_goal', data=df, ax = ax,
           order = list(medians.index))


#pos = range(len(medians))
#for tick,label in zip(pos,ax.get_xticklabels()):
#    ax.text(pos[tick], 70000,"n: " + str(medians['count'][tick]),
#            ha='center', size='small', color='k', weight='light')
#    ax.text(pos[tick], 65000, medians['median'][tick],
#           ha = 'center', size='small', color='k', weight='light')

ax.set_ylabel('USD Goal')
ax.set_xlabel('Core Category')
ax.set_title("USD Goal by Category ")
    
plt.show()

fig.savefig("img/category_to_usd_goal_sorted_ids_outliers", bbox_inches='tight')

# %%
from scipy.stats import ttest_ind

usd_analysis = dict()
for c in categories:
    usd_analysis[c] = df[df.category_core == c].usd_goal

# %%
yeet = pd.DataFrame(columns=['cat_a','cat_b','t','p'])
for a in range(15):
    cat_a = categories[a]
    for b in range(15):
        cat_b = categories[b]
        sci_t_test = ttest_ind(usd_analysis[cat_a], usd_analysis[cat_b])
        stats = dict({'cat_a':cat_a, 'cat_b':cat_b,'t':np.abs(sci_t_test[0]),'p':sci_t_test[1]})
        yeet = yeet.append(stats, ignore_index = True)

# %%
yeetplus = yeet.pivot('cat_a', 'cat_b', 'p')

# %%
fig, ax = plt.subplots(figsize = (15, 6))

mask = np.zeros_like(yeetplus)
mask[np.triu_indices_from(mask)] = True

with sns.axes_style("white"):
    ax = sns.heatmap(yeetplus,vmax = .05,annot=True, cmap = "Blues_r")
plt.title("p-values")
plt.ylabel("Categories 1")
plt.xlabel("Categories 2")

plt.show()
fig.savefig("img/p_value_category_usd_goal", bbox_inches='tight')

# %%
df[df.category_core =='publishing'].usd_goal.describe()['count':'std']
# Out:
# count     17098.000000
# mean      10561.952671
# std      208114.199314
# Name: usd_goal, dtype: float64

# %%
df[df.category_core =='journalism'].usd_goal.describe()['count':'std']
# Out:
# count    3.706000e+03
# mean     5.596014e+04
# std      1.668095e+06
# Name: usd_goal, dtype: float64

# %% [markdown]
# For deep blue values that are well below the %5 threshold, we are more likely to reject the null hypothesis that the average usd goal between categories are equal.
# This tells us that when we're comparing goals between success and failure, it isn't enough to just take the group of success and failure as a whole and would need to compare between categories too.

# %%
f, p = f_oneway(df[df.category_core == 'food'].usd_goal, 
               df[df.category_core == 'film & video'].usd_goal,
               df[df.category_core == 'publishing'].usd_goal,
               df[df.category_core == 'photography'].usd_goal,
               df[df.category_core == 'crafts'].usd_goal,
               df[df.category_core == 'music'].usd_goal,
               df[df.category_core == 'fashion'].usd_goal,
               df[df.category_core == 'theater'].usd_goal,
               df[df.category_core == 'journalism'].usd_goal,
               df[df.category_core == 'technology'].usd_goal,
               df[df.category_core == 'games'].usd_goal,
               df[df.category_core == 'comics'].usd_goal,
               df[df.category_core == 'dance'].usd_goal,
               df[df.category_core == 'design'].usd_goal,
               df[df.category_core == 'art'].usd_goal,)
print ('One-way ANOVA')
print ('=============')
 
print ('F value:', f)
print ('P value:', p, '\n')
# Out:
# One-way ANOVA
# =============
# F value: 11.25978941791777
# P value: 2.1850894957732193e-26

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison

mc = MultiComparison(df['usd_goal'], df['category_core'])
result = mc.tukeyhsd()
 
print(result)
print(mc.groupsunique)
# Out:
#           Multiple Comparison of Means - Tukey HSD,FWER=0.05
# =====================================================================
#    group1       group2      meandiff     lower        upper    reject
# ---------------------------------------------------------------------
#     art         comics    -26177.4919 -80738.1303   28383.1465 False
#     art         crafts    -24039.5395 -81978.2325   33899.1535 False
#     art         dance     -25937.1506  -99926.69    48052.3888 False
#     art         design     20492.9781 -35882.2551   76868.2114 False
#     art        fashion    -17559.6154 -66158.4165   31039.1858 False
#     art      film & video  75098.7355  38120.565   112076.9061  True
#     art          food      16211.5397 -26593.2063   59016.2857 False
#     art         games      2332.5395  -43376.7275   48041.8066 False
#     art       journalism   23049.3759 -44691.4544   90790.2062 False
#     art         music     -22260.9285 -59027.3886   14505.5317 False
#     art      photography  -19981.2346 -76970.7648   37008.2955 False
#     art       publishing  -22348.8102 -62408.0904    17710.47  False
#     art       technology   37912.3294  -1715.3803   77540.039  False
#     art        theater     2656.6988  -58725.8078   64039.2054 False
#    comics       crafts     2137.9524   -66969.525   71245.4298 False
#    comics       dance       240.3413  -82786.1799   83266.8625 False
#    comics       design      46670.47  -21131.5816  114472.5216 False
#    comics      fashion     8617.8765  -52870.2911   70106.0441 False
#    comics    film & video 101276.2274  48490.4682  154061.9866  True
#    comics        food      42389.0316  -14630.242   99408.3052 False
#    comics       games      28510.0314 -30720.7745   87740.8374 False
#    comics     journalism   49226.8678 -28282.9469  126736.6824 False
#    comics       music      3916.5634  -48721.1025   56554.2293 False
#    comics    photography   6196.2573  -62117.4151   74509.9296 False
#    comics     publishing   3828.6817  -51159.4735   58816.8369 False
#    comics     technology   64089.8212  9415.2691   118764.3734  True
#    comics      theater     28834.1907  -43184.997  100853.3784 False
#    crafts       dance      -1897.6111  -87182.03    83386.8078 False
#    crafts       design     44532.5176 -26016.3809  115081.4162 False
#    crafts      fashion     6479.9241  -58024.5226   70984.3707 False
#    crafts    film & video  99138.275   42867.8098  155408.7403  True
#    crafts        food      40251.0792 -20008.5794  100510.7377 False
#    crafts       games      26372.079   -35984.294   88728.452  False
#    crafts     journalism   47088.9154 -32834.7998  127012.6305 False
#    crafts       music       1778.611  -54352.9554   57910.1775 False
#    crafts    photography   4058.3048  -66982.4349   75099.0446 False
#    crafts     publishing   1690.7293  -56650.7319   60032.1904 False
#    crafts     technology   61951.8688  3905.8911   119997.8466  True
#    crafts      theater     26696.2383 -47914.7011  101307.1777 False
#    dance        design     46430.1287 -37799.9543  130660.2117 False
#    dance       fashion     8377.5352  -70858.7155   87613.786  False
#    dance     film & video 101035.8861  28345.2743   173726.498  True
#    dance         food      42148.6903 -33672.0604   117969.441 False
#    dance        games      28269.6902 -49227.9037   105767.284 False
#    dance      journalism   48986.5265 -43237.9824  141211.0354 False
#    dance        music      3676.2221  -68906.9202   76259.3645 False
#    dance     photography    5955.916  -78686.5468   90598.3788 False
#    dance      publishing   3588.3404  -70717.0153   77893.6961 False
#    dance      technology    63849.48  -10224.1005  137923.0605 False
#    dance       theater     28593.8494 -59066.5868  116254.2856 False
#    design      fashion    -38052.5935 -101156.4635  25051.2765 False
#    design    film & video  54605.7574   -53.5513   109265.0662 False
#    design        food      -4281.4385  -63039.427   54476.5501 False
#    design       games     -18160.4386 -79066.8588   42745.9817 False
#    design     journalism   2556.3978  -76241.2864   81354.0819 False
#    design       music     -42753.9066 -97270.2118   11762.3986 False
#    design    photography  -40474.2128 -110245.7075  29297.282  False
#    design     publishing  -42841.7883 -99630.8794   13947.3028 False
#    design     technology   17419.3512 -39066.1364   73904.8388 False
#    design      theater    -17836.2793 -91239.7333   55567.1747 False
#   fashion    film & video  92658.3509  46060.9628  139255.7391  True
#   fashion        food      33771.1551 -17572.5667   85114.8769 False
#   fashion       games      19892.1549 -33896.9571   73681.267  False
#   fashion     journalism   40608.9913 -32826.3651  114044.3477 False
#   fashion       music      -4701.3131 -51130.8735   41728.2473 False
#   fashion    photography   -2421.6192 -66074.8834   61231.6449 False
#   fashion     publishing   -4789.1948 -53867.4733   44289.0836 False
#   fashion     technology   55471.9448  6745.2902   104198.5993  True
#   fashion      theater     20216.3142 -47398.3558   87830.9842 False
# film & video     food     -58887.1959 -99405.3324  -18369.0593  True
# film & video    games      -72766.196 -116341.5353 -29190.8566  True
# film & video  journalism  -52049.3596 -118368.9887  14270.2694 False
# film & video    music      -97359.664 -131436.7193 -63282.6087  True
# film & video photography  -95079.9702 -150372.6429 -39787.2974  True
# film & video  publishing  -97447.5457 -135053.6495  -59841.442  True
# film & video  technology  -37186.4062 -74332.4488    -40.3636   True
# film & video   theater    -72442.0367 -132252.4474  -12631.626  True
#     food        games     -13879.0001 -62496.6038   34738.6035 False
#     food      journalism   6837.8362  -62898.4842   76574.1566 False
#     food        music     -38472.4681 -78797.4838   1852.5475  False
#     food     photography  -36192.7743 -95540.4014   23154.8528 False
#     food      publishing  -38560.3499 -81908.7088   4788.0091  False
#     food      technology   21700.7897 -21249.0609   64650.6403 False
#     food       theater    -13554.8409 -77132.7176   50023.0359 False
#    games      journalism   20716.8363 -50839.0522   92272.7249 False
#    games        music      -24593.468 -67989.2938   18802.3578 False
#    games     photography  -22313.7742 -83789.2299   39161.6815 False
#    games      publishing  -24681.3498 -70900.0801   21537.3806 False
#    games      technology   35579.7898 -10265.3896   81424.9692 False
#    games       theater      324.1593  -65244.4096   65892.7281 False
#  journalism     music     -45310.3044 -111512.1222  20891.5135 False
#  journalism  photography  -43030.6105 -122268.9513  36207.7302 False
#  journalism   publishing  -45398.1861 -113483.8236  22687.4514 False
#  journalism   technology   14862.9535 -52969.6602   82695.5671 False
#  journalism    theater    -20392.6771 -102847.0294  62061.6752 False
#    music     photography   2279.6938  -52871.6176   57431.0053 False
#    music      publishing    -87.8817   -37485.83    37310.0665 False
#    music      technology   60173.2578  23237.9634   97108.5523  True
#    music       theater     24917.6273 -34762.1241   84597.3786 False
# photography   publishing   -2367.5756 -59766.5345   55031.3834 False
# photography   technology   57893.564    794.9656   114992.1623  True
# photography    theater     22637.9335 -51238.3596   96514.2265 False
#  publishing   technology   60261.1396  20046.8471   100475.432  True
#  publishing    theater     25005.509   -36757.312    86768.33  False
#  technology    theater    -35255.6305  -96739.413   26228.1519 False
# ---------------------------------------------------------------------
# ['art' 'comics' 'crafts' 'dance' 'design' 'fashion' 'film & video' 'food'
#  'games' 'journalism' 'music' 'photography' 'publishing' 'technology'
#  'theater']

# %%
tukey = pd.DataFrame(data=result._results_table.data[1:], columns=result._results_table.data[0])

# %%
tukey[tukey.reject == True]
# Out:
#            group1        group2     meandiff        lower        upper  reject
# 5             art  film & video   75098.7355   38120.5650  112076.9061    True
# 18         comics  film & video  101276.2274   48490.4682  154061.9866    True
# 25         comics    technology   64089.8212    9415.2691  118764.3734    True
# 30         crafts  film & video   99138.2750   42867.8098  155408.7403    True
# 37         crafts    technology   61951.8688    3905.8911  119997.8466    True
# 41          dance  film & video  101035.8861   28345.2743  173726.4980    True
# 60        fashion  film & video   92658.3509   46060.9628  139255.7391    True
# 67        fashion    technology   55471.9448    6745.2902  104198.5993    True
# 69   film & video          food  -58887.1959  -99405.3324  -18369.0593    True
# 70   film & video         games  -72766.1960 -116341.5353  -29190.8566    True
# 72   film & video         music  -97359.6640 -131436.7193  -63282.6087    True
# 73   film & video   photography  -95079.9702 -150372.6429  -39787.2974    True
# 74   film & video    publishing  -97447.5457 -135053.6495  -59841.4420    True
# 75   film & video    technology  -37186.4062  -74332.4488     -40.3636    True
# 76   film & video       theater  -72442.0367 -132252.4474  -12631.6260    True
# 97          music    technology   60173.2578   23237.9634   97108.5523    True
# 100   photography    technology   57893.5640     794.9656  114992.1623    True
# 102    publishing    technology   60261.1396   20046.8471  100475.4320    True

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import six
def render_mpl_table(data, col_width=3.0, row_height=0.625, font_size=14,
                     header_color='#40466e', row_colors=['#f1f1f2', 'w'], edge_color='w',
                     bbox=[0, 0, 1, 1], header_columns=0,
                     ax=None, **kwargs):
    if ax is None:
        size = (np.array(data.shape[::-1]) + np.array([0, 1])) * np.array([col_width, row_height])
        fig, ax = plt.subplots(figsize=size)
        ax.axis('off')

    mpl_table = ax.table(cellText=data.values, bbox=bbox, colLabels=data.columns, **kwargs)

    mpl_table.auto_set_font_size(False)
    mpl_table.set_fontsize(font_size)
    
    plt.savefig('img/tukey.png')

    for k, cell in six.iteritems(mpl_table._cells):
        cell.set_edgecolor(edge_color)
        if k[0] == 0 or k[1] < header_columns:
            cell.set_text_props(weight='bold', color='w')
            cell.set_facecolor(header_color)
        else:
            cell.set_facecolor(row_colors[k[0]%len(row_colors) ])
    return ax

render_mpl_table(tukey[tukey.reject == True], header_columns=0, col_width=2.0)

# %%
rejections = tukey[tukey.reject == True].group1
rejections = rejections.append(tukey[tukey.reject == True].group2)

c = Counter(rejections)
print(c)
# Out:
# Counter({'film & video': 12, 'technology': 7, 'comics': 2, 'crafts': 2, 'fashion': 2, 'music': 2, 'photography': 2, 'publishing': 2, 'art': 1, 'dance': 1, 'food': 1, 'games': 1, 'theater': 1})

# %% [markdown]
# ## Months

# %%
df['created_at_month'] = df.created_at.dt.strftime('%B')
df.groupby(by='created_at_month').reach_goal.mean().sort_values()
# Out:
# created_at_month
# July         0.502409
# December     0.549281
# June         0.552649
# November     0.553224
# August       0.553316
# April        0.569419
# October      0.570924
# September    0.570944
# May          0.573774
# January      0.581404
# February     0.582311
# March        0.592981
# Name: reach_goal, dtype: float64

# %%
df['deadline_month'] = df.deadline.dt.strftime('%B')
df.groupby(by='deadline_month').reach_goal.mean().sort_values()
# Out:
# deadline_month
# January      0.521900
# August       0.525653
# September    0.530028
# February     0.559056
# December     0.561119
# June         0.564398
# July         0.564689
# October      0.571588
# May          0.574565
# November     0.582891
# March        0.585760
# April        0.595784
# Name: reach_goal, dtype: float64

# %%
df['ct_dt_month'] = df.created_at.dt.strftime('%B') + ' - ' + df.deadline.dt.strftime('%B')

ct_dt_group = df.groupby(by='ct_dt_month').reach_goal

ct_dt_group.mean().sort_values()[
    ct_dt_group.count().sort_values() > 1000
]
# Out:
# ct_dt_month
# July - August           0.460282
# December - January      0.490043
# July - September        0.502878
# June - July             0.508511
# August - September      0.511682
# October - January       0.517647
# November - December     0.520298
# May - June              0.524841
# April - May             0.531324
# January - February      0.532485
# September - October     0.534270
# November - January      0.543415
# February - March        0.545440
# October - November      0.550875
# December - February     0.563819
# March - April           0.565204
# August - October        0.569469
# April - June            0.570525
# June - August           0.571357
# October - December      0.575509
# January - March         0.588062
# September - November    0.589709
# July - October          0.597812
# March - May             0.598463
# November - February     0.599340
# February - April        0.599427
# June - September        0.599664
# May - July              0.601574
# September - December    0.612769
# August - November       0.623592
# February - May          0.625262
# May - August            0.628123
# December - March        0.635243
# April - July            0.638889
# March - June            0.647712
# January - April         0.652301
# Name: reach_goal, dtype: float64

# %%
## Getting categories into individual fields
create_month_analysis = dict()
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October',
             'November', 'December']

for m in months:
    create_month_analysis[m] = df[df.created_at_month == m].reach_goal
    
## Running bootstrap
bscm_analysis = dict()

N_rep = 1000
for c in create_month_analysis:
    bscm_analysis[c] = draw_bs_reps(create_month_analysis[c], success_rate, N_rep)

# %%
fig, ax = plt.subplots(figsize = (20, 5))

for bs in bscm_analysis:
    ax = plt.hist(bscm_analysis[bs], alpha = 0.5, bins = 30, label = bs)

plt.title("Bootstrap Success Rate by Created Month")
plt.xlabel('Success Rate')
plt.ylabel('Frequency')
plt.legend()
plt.show()
fig.savefig("img/bootstrap_success_rate_by_created_month", bbox_inches='tight')

# %%
## Getting categories into individual fields
deadline_analysis = dict()
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October',
             'November', 'December']

for m in months:
    deadline_analysis[m] = df[df.deadline_month == m].reach_goal
    
## Running bootstrap
bsd_analysis = dict()

N_rep = 1000
for c in deadline_analysis:
    bsd_analysis[c] = draw_bs_reps(deadline_analysis[c], success_rate, N_rep)
    
fig, ax = plt.subplots(figsize = (20, 5))

for bs in bsd_analysis:
    ax = plt.hist(bsd_analysis[bs], alpha = 0.5, bins = 30, label = bs)

plt.title("Bootstrap Success Rate by Category")
plt.xlabel('Success Rate')
plt.ylabel('Frequency')
plt.legend()
plt.show()
fig.savefig("img/bootstrap_sr_category_month", bbox_inches='tight')
